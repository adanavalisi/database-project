# %%
from pymongo.mongo_client import MongoClient
from pymongo import TEXT
import pymongo
import string
from itertools import chain
import nltk
import re
import time
from Levenshtein import distance

# %% [markdown]
# ## CONNECTION CHECK

# %%
uri = "mongodb+srv://duskmane:MQlA2Nm3dMxGhO3c@ads-cluster.tfi3k0w.mongodb.net/"
client = MongoClient(uri)

try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
client.list_database_names()
# Out:
# ['ex_words_01', 'admin', 'local']

# %%
ex_words = client.ex_words_01.ex_words_01

# %%
ex_words.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'word_1': {'v': 2, 'key': [('word', 1)]},
#  'word_text': {'v': 2,
#   'key': [('_fts', 'text'), ('_ftsx', 1)],
#   'weights': SON([('word', 1)]),
#   'default_language': 'english',
#   'language_override': 'language',
#   'textIndexVersion': 3}}

# %% [markdown]
# ### Adding indexes

# %%
#ex_words.create_index('word')
#ex_words.create_index([('word', TEXT)])

# %% [markdown]
# ### Adding multiwords inside the database since there is non at the beginning

# %%
# multi_words = ['future generation', 'greenhouse gas', 'economic landscape', 'environmental policy', 'Soil pollution', 'economic growth', 'sustainable lifestyle', 'environmental education', 'collective responsibility', 'critical thinking', 'printing press', 'scientific methods', 'European culture', 'ancient civilizations', 'sustainable energy', 'national parks', 'urban life', 'parliamentary system', 'positive change', 'international cooperation']
# for multi_word in multi_words:
#     ex_words.insert_one({"word": multi_word})

# %% [markdown]
# ## DATA PREPROCESS

# %%
def get_words_from_file(file_name):
    with open(file_name) as f:
        lines = f.readlines()
    
    new_l = ''

    for line in lines:
        if line.strip():
            new_l += ' ' + (line.lower().strip())
            
    punc_removed = re.sub(r'[^\w\s-]','',new_l)
    tokenized_text = nltk.word_tokenize(punc_removed)
    return tokenized_text

# %%
def get_multiwords4(words, skip):
    hexagon_w = [f"{words[i]} {words[i+1]} {words[i+2]} {words[i+3]}" 
                 for i in range(0, len(words), (5 - skip)) if i < len(words) - (6 - skip)]
    
    return list(chain(hexagon_w))

# %%
def get_multiwords5(words, skip):
    hexagon_w = [f"{words[i]} {words[i+1]} {words[i+2]} {words[i+3]} {words[i+4]}" 
                 for i in range(0, len(words), (6 - skip)) if i < len(words) - (7 - skip)]
    
    return list(chain(hexagon_w))

# %%
def get_multiwords6(words, skip):
    hexagon_w = [f"{words[i]} {words[i+1]} {words[i+2]} {words[i+3]} {words[i+4]} {words[i+5]}" 
                 for i in range(0, len(words), (7 - skip)) if i < len(words) - (8 - skip)]
    
    return list(chain(hexagon_w))

# %%
def get_multiwords8(words, skip):
    hexagon_w = [f"{words[i]} {words[i+1]} {words[i+2]} {words[i+3]} {words[i+4]} {words[i+5]} {words[i+6]} {words[i+7]}" 
                 for i in range(0, len(words), (9 - skip)) if i < len(words) - (10 - skip)]
    
    return list(chain(hexagon_w))

# %%
def get_multiwords10(words, skip):
    hexagon_w = [f"{words[i]} {words[i+1]} {words[i+2]} {words[i+3]} {words[i+4]} {words[i+5]} {words[i+6]} {words[i+7]} {words[i+8]} {words[i+9]} " 
                 for i in range(0, len(words), (11 - skip)) if i < len(words) - (12 - skip)]
    
    return list(chain(hexagon_w))

# %%
file_name = 'environment_2k.txt'
max_multi_words = 3
words = get_words_from_file(file_name)
multiwords = get_multiwords5(words,max_multi_words)

# %%
print(f'Text length: {len(words)} words')
print(f'Unique words: {len(set(words))}')
print(f'Multiwords length: {len(multiwords)}')
# Out:
# Text length: 1999 words
# Unique words: 794
# Multiwords length: 665

# %% [markdown]
# ## QUERY TESTING

# %% [markdown]
# **Using $in**

# %%
words_query = {"word": {"$in": words}}
results = list(ex_words.find(words_query))
results = [item['word'] for item in results]

# %%
len(results)
# Out:
# 780

# %%
#results

# %%
words_not_found = []
for word in words:
    if word not in results:
        words_not_found.append(word)
        
words_not_found = list(set(words_not_found))

# %%
print(words_not_found)
# Out:
# ['17th', 'multi-faceted', 'year-round', 'well-being', '19th', 'gameits', 'far-reaching', 'non-governmental', 'eco-friendly', 'human-induced', '1980', 'self-improvement', '14th', 'multi-billion-dollar']

# %%
len(words_not_found)
# Out:
# 14

# %% [markdown]
# **Using $in for multiwords**

# %%
multiwords_query = {"word": {"$in": multiwords}}
results_mw = list(ex_words.find(multiwords_query))
results_mw = [item['word'] for item in results_mw]

# %%
len(results_mw)
# Out:
# 0

# %%
results_mw
# Out:
# []

# %% [markdown]
# ## EXPLAIN

# %%
explain_result = ex_words.find({"word": {"$in": words}}).explain()
print(explain_result['executionStats']['executionTimeMillis'])
explain_result = ex_words.find(multiwords_query).explain()
print(explain_result['executionStats']['executionTimeMillis'])
# Out:
# 5
# 1

# %% [markdown]
# ## SINGLE WORDS COULD NOT BE FOUND

# %%
startt = time.time()

levenshtein_results = {}
levenshtein_threshold = 3

for word in words_not_found: 
    
    levenshtein_candidates = ex_words.find({"$text": {"$search": word}})

    levenshtein_candidates = [candidate["word"] for candidate in levenshtein_candidates]
    
    if any(char for char in word if char.isdigit() or char == '-'):
            
        clean_word = re.sub(r'[0-9-]', '', word)

        new_candidates = ex_words.find({"$text": {"$search": clean_word}})
        new_candidates = [candidate["word"] for candidate in new_candidates]

        all_candidates = list(set(levenshtein_candidates + new_candidates))
        
    else:
        all_candidates = levenshtein_candidates

    min_distance = float('inf')
    
    for candidate in all_candidates:
        
        current_distance = distance(word, candidate)
        
        if current_distance <= levenshtein_threshold and current_distance < min_distance:
            
            min_distance = current_distance
            levenshtein_results[word] = (candidate)

endt = time.time()

# %%
endt-startt
# Out:
# 1.022698163986206

# %%
levenshtein_results
# Out:
# {'17th': 'th',
#  'multi-faceted': 'multifaceted',
#  'well-being': 'wellbeing',
#  '19th': 'th',
#  'non-governmental': 'nongovernmental',
#  'eco-friendly': 'ecofriend',
#  '14th': 'th'}

# %% [markdown]
# ### MULTI WORD SEARCH

# %%
multiwords
# Out:
# ['the environment is a precious',
#  'a precious and fragile entity',
#  'fragile entity that sustains life',
#  'sustains life on earth as',
#  'earth as the custodians of',
#  'custodians of this planet it',
#  'planet it is our responsibility',
#  'our responsibility to protect and',
#  'protect and preserve it for',
#  'it for future generations the',
#  'generations the alarming rate at',
#  'rate at which human activities',
#  'human activities are causing environmental',
#  'causing environmental degradation has raised',
#  'has raised concerns worldwide from',
#  'worldwide from deforestation to pollution',
#  'to pollution the signs of',
#  'signs of environmental distress are',
#  'distress are evident in this',
#  'in this essay we will',
#  'we will explore the importance',
#  'the importance of protecting the',
#  'protecting the environment the current',
#  'the current threats it faces',
#  'it faces and the actions',
#  'the actions individuals and societies',
#  'and societies can take to',
#  'take to ensure a sustainable',
#  'a sustainable future at the',
#  'at the heart of environmental',
#  'of environmental protection lies the',
#  'lies the understanding that the',
#  'that the earths ecosystems are',
#  'ecosystems are interconnected and interdependent',
#  'and interdependent the delicate balance',
#  'delicate balance of nature which',
#  'nature which has evolved over',
#  'evolved over millions of years',
#  'of years is being disrupted',
#  'being disrupted by human activities',
#  'human activities deforestation driven by',
#  'driven by the demand for',
#  'demand for timber and agricultural',
#  'and agricultural expansion leads to',
#  'leads to the loss of',
#  'loss of biodiversity and contributes',
#  'and contributes to climate change',
#  'climate change the destruction of',
#  'destruction of natural habitats displaces',
#  'habitats displaces countless species disrupting',
#  'species disrupting the intricate web',
#  'intricate web of life that',
#  'life that supports ecosystems worldwide',
#  'ecosystems worldwide one of the',
#  'of the most pressing issues',
#  'pressing issues threatening the environment',
#  'the environment is climate change',
#  'climate change the burning of',
#  'burning of fossil fuels releases',
#  'fuels releases greenhouse gases such',
#  'gases such as carbon dioxide',
#  'carbon dioxide and methane into',
#  'methane into the atmosphere leading',
#  'atmosphere leading to a gradual',
#  'a gradual but significant increase',
#  'significant increase in global temperatures',
#  'global temperatures the consequences of',
#  'consequences of climate change are',
#  'change are far-reaching and include',
#  'and include rising sea levels',
#  'sea levels extreme weather events',
#  'weather events and disruptions to',
#  'disruptions to ecosystems protecting the',
#  'protecting the environment means addressing',
#  'means addressing the root causes',
#  'root causes of climate change',
#  'climate change and transitioning to',
#  'transitioning to sustainable energy sources',
#  'energy sources pollution in its',
#  'in its various forms poses',
#  'forms poses another significant threat',
#  'significant threat to the environment',
#  'the environment air pollution primarily',
#  'pollution primarily caused by industrial',
#  'by industrial emissions and vehicular',
#  'and vehicular exhaust affects human',
#  'affects human health and contributes',
#  'and contributes to climate change',
#  'climate change water pollution resulting',
#  'pollution resulting from the discharge',
#  'the discharge of industrial waste',
#  'industrial waste and agricultural runoff',
#  'agricultural runoff contaminates rivers lakes',
#  'rivers lakes and oceans harming',
#  'oceans harming aquatic life and',
#  'life and endangering human populations',
#  'human populations that rely on',
#  'rely on these water sources',
#  'water sources soil pollution often',
#  'pollution often caused by improper',
#  'by improper disposal of hazardous',
#  'of hazardous waste degrades the',
#  'degrades the quality of agricultural',
#  'of agricultural land and poses',
#  'and poses risks to human',
#  'to human health to protect',
#  'to protect the environment effectively',
#  'environment effectively individuals and societies',
#  'and societies must adopt a',
#  'adopt a multi-faceted approach education',
#  'approach education and awareness play',
#  'awareness play a crucial role',
#  'crucial role in fostering a',
#  'fostering a sense of responsibility',
#  'of responsibility and instigating change',
#  'instigating change governments non-governmental organizations',
#  'non-governmental organizations ngos and educational',
#  'and educational institutions should collaborate',
#  'should collaborate to implement comprehensive',
#  'implement comprehensive environmental education programs',
#  'education programs that highlight the',
#  'highlight the interconnectedness of all',
#  'of all living things and',
#  'things and the impact of',
#  'impact of human activities on',
#  'activities on the planet policy',
#  'planet policy initiatives are instrumental',
#  'are instrumental in promoting environmental',
#  'promoting environmental protection on a',
#  'on a larger scale governments',
#  'scale governments worldwide should enact',
#  'should enact and enforce stringent',
#  'enforce stringent environmental regulations that',
#  'regulations that limit harmful practices',
#  'harmful practices such as deforestation',
#  'as deforestation and pollution incentives',
#  'pollution incentives for sustainable practices',
#  'sustainable practices such as renewable',
#  'as renewable energy adoption and',
#  'adoption and conservation efforts can',
#  'efforts can encourage businesses and',
#  'businesses and industries to embrace',
#  'to embrace environmentally friendly alternatives',
#  'friendly alternatives international cooperation is',
#  'cooperation is vital as environmental',
#  'as environmental issues transcend national',
#  'transcend national borders and require',
#  'and require a collective effort',
#  'collective effort to address effectively',
#  'address effectively sustainable development is',
#  'development is a key concept',
#  'key concept in the quest',
#  'the quest for environmental protection',
#  'environmental protection it entails meeting',
#  'entails meeting the needs of',
#  'needs of the present without',
#  'present without compromising the ability',
#  'the ability of future generations',
#  'future generations to meet their',
#  'meet their own needs sustainable',
#  'needs sustainable practices encompass a',
#  'encompass a wide range of',
#  'range of activities from sustainable',
#  'from sustainable agriculture and forestry',
#  'and forestry to the promotion',
#  'the promotion of clean and',
#  'clean and renewable energy sources',
#  'energy sources investing in green',
#  'in green technologies and eco-friendly',
#  'and eco-friendly solutions can spur',
#  'can spur economic growth while',
#  'growth while minimizing the ecological',
#  'the ecological footprint of human',
#  'of human activities conservation efforts',
#  'conservation efforts are integral to',
#  'integral to protecting the environment',
#  'the environment and preserving biodiversity',
#  'preserving biodiversity establishing and maintaining',
#  'and maintaining protected areas such',
#  'areas such as national parks',
#  'national parks and wildlife reserves',
#  'wildlife reserves provides safe havens',
#  'safe havens for endangered species',
#  'endangered species and allows ecosystems',
#  'allows ecosystems to recover from',
#  'recover from human-induced disturbances additionally',
#  'disturbances additionally reforestation initiatives can',
#  'initiatives can help restore ecosystems',
#  'restore ecosystems that have been',
#  'have been degraded by deforestation',
#  'by deforestation providing habitats for',
#  'habitats for wildlife and contributing',
#  'and contributing to carbon sequestration',
#  'carbon sequestration individuals also play',
#  'also play a crucial role',
#  'crucial role in environmental protection',
#  'environmental protection adopting sustainable lifestyle',
#  'sustainable lifestyle choices such as',
#  'such as reducing energy consumption',
#  'energy consumption minimizing waste and',
#  'waste and choosing eco-friendly products',
#  'eco-friendly products can collectively make',
#  'collectively make a significant impact',
#  'significant impact the power of',
#  'power of individual actions should',
#  'actions should not be underestimated',
#  'be underestimated as small changes',
#  'small changes in behavior can',
#  'behavior can lead to substantial',
#  'to substantial positive outcomes when',
#  'outcomes when multiplied across communities',
#  'across communities and societies the',
#  'societies the responsible management of',
#  'management of natural resources is',
#  'resources is fundamental to environmental',
#  'to environmental protection overexploitation of',
#  'overexploitation of resources driven by',
#  'driven by unsustainable consumption patterns',
#  'consumption patterns depletes the earths',
#  'the earths finite resources and',
#  'resources and accelerates environmental degradation',
#  'environmental degradation adopting circular economy',
#  'circular economy principles which emphasize',
#  'which emphasize recycling and reducing',
#  'and reducing waste can help',
#  'can help minimize the environmental',
#  'the environmental impact of resource',
#  'of resource extraction and consumption',
#  'and consumption in conclusion protecting',
#  'conclusion protecting the environment is',
#  'environment is an urgent and',
#  'urgent and collective responsibility that',
#  'responsibility that requires the concerted',
#  'the concerted efforts of individuals',
#  'of individuals communities governments and',
#  'governments and international organizations the',
#  'organizations the consequences of inaction',
#  'of inaction are severe and',
#  'severe and threaten the well-being',
#  'the well-being of current and',
#  'current and future generations by',
#  'generations by embracing sustainable practices',
#  'sustainable practices raising awareness enacting',
#  'awareness enacting and enforcing environmental',
#  'enforcing environmental policies and fostering',
#  'and fostering a sense of',
#  'sense of environmental stewardship we',
#  'stewardship we can work towards',
#  'work towards a harmonious coexistence',
#  'harmonious coexistence with nature the',
#  'nature the time to act',
#  'to act is now and',
#  'now and the choices we',
#  'choices we make today will',
#  'today will shape the future',
#  'the future of our planet',
#  'our planet for generations to',
#  'generations to come the renaissance',
#  'the renaissance was a period',
#  'a period of great cultural',
#  'great cultural and intellectual change',
#  'intellectual change that took place',
#  'took place in europe from',
#  'europe from the 14th to',
#  '14th to the 17th centuries',
#  '17th centuries it was a',
#  'was a time of renewed',
#  'of renewed interest in classical',
#  'in classical learning art and',
#  'art and literature as well',
#  'as well as a period',
#  'a period of great social',
#  'great social and political upheaval',
#  'political upheaval the renaissance was',
#  'renaissance was characterized by a',
#  'by a number of key',
#  'of key developments including a',
#  'including a renewed interest in',
#  'interest in classical learning during',
#  'learning during the renaissance scholars',
#  'renaissance scholars began to rediscover',
#  'to rediscover and study the',
#  'study the works of ancient',
#  'of ancient greek and roman',
#  'and roman writers artists and',
#  'artists and philosophers this led',
#  'this led to a new',
#  'a new appreciation for classical',
#  'for classical ideals of beauty',
#  'of beauty harmony and proportion',
#  'and proportion which had a',
#  'had a profound influence on',
#  'influence on renaissance art and',
#  'art and literature the development',
#  'the development of humanism humanism',
#  'humanism humanism was a new',
#  'a new philosophy that emphasized',
#  'that emphasized the importance of',
#  'importance of human reason and',
#  'reason and the pursuit of',
#  'pursuit of knowledge humanists believed',
#  'humanists believed that individuals could',
#  'individuals could achieve great things',
#  'great things through their own',
#  'their own efforts and they',
#  'and they encouraged the development',
#  'the development of critical thinking',
#  'critical thinking creativity and self-improvement',
#  'and self-improvement the rise of',
#  'rise of individualism during the',
#  'during the renaissance there was',
#  'there was a growing emphasis',
#  'growing emphasis on the importance',
#  'the importance of the individual',
#  'the individual humanists believed that',
#  'believed that each person was',
#  'person was unique and had',
#  'and had the potential to',
#  'potential to make a difference',
#  'a difference in the world',
#  'the world this led to',
#  'led to a new appreciation',
#  'new appreciation for personal freedom',
#  'personal freedom and expression the',
#  'expression the development of new',
#  'of new artistic and literary',
#  'and literary forms the renaissance',
#  'the renaissance saw the development',
#  'the development of a number',
#  'a number of new artistic',
#  'new artistic and literary forms',
#  'literary forms including the sonnet',
#  'the sonnet the novel and',
#  'novel and the essay these',
#  'essay these new forms allowed',
#  'forms allowed artists and writers',
#  'and writers to explore new',
#  'explore new ideas and techniques',
#  'and techniques and they helped',
#  'they helped to shape the',
#  'shape the way we think',
#  'we think about the world',
#  'the world today the growth',
#  'the growth of urban life',
#  'urban life during the renaissance',
#  'the renaissance there was a',
#  'was a significant growth in',
#  'growth in urban life this',
#  'life this was due in',
#  'due in part to the',
#  'to the development of new',
#  'of new technologies such as',
#  'such as the printing press',
#  'printing press which made it',
#  'made it possible to produce',
#  'to produce books more cheaply',
#  'more cheaply and efficiently as',
#  'efficiently as a result more',
#  'result more people had access',
#  'had access to education and',
#  'education and information which led',
#  'which led to a more',
#  'a more literate and informed',
#  'and informed population the renaissance',
#  'the renaissance was a period',
#  'a period of great cultural',
#  'great cultural and intellectual ferment',
#  'intellectual ferment it was a',
#  'was a time of great',
#  'of great change and innovation',
#  'and innovation and it had',
#  'it had a profound impact',
#  'profound impact on the development',
#  'the development of western civilization',
#  'western civilization some of the',
#  'of the most important achievements',
#  'important achievements of the renaissance',
#  'the renaissance include the development',
#  'the development of new scientific',
#  'new scientific methods during the',
#  'during the renaissance scientists began',
#  'scientists began to use new',
#  'use new methods of observation',
#  'of observation and experimentation to',
#  'experimentation to study the natural',
#  'the natural world this led',
#  'this led to a number',
#  'a number of important discoveries',
#  'important discoveries such as the',
#  'as the heliocentric model of',
#  'model of the solar system',
#  'solar system the invention of',
#  'invention of the printing press',
#  'printing press the printing press',
#  'printing press was one of',
#  'one of the most important',
#  'most important inventions of the',
#  'of the renaissance it made',
#  'it made it possible to',
#  'possible to produce books more',
#  'books more cheaply and efficiently',
#  'and efficiently which led to',
#  'led to a wider dissemination',
#  'wider dissemination of knowledge the',
#  'knowledge the development of new',
#  'of new forms of government',
#  'of government during the renaissance',
#  'the renaissance there were a',
#  'were a number of challenges',
#  'of challenges to the traditional',
#  'the traditional feudal system of',
#  'system of government this led',
#  'this led to the development',
#  'the development of new forms',
#  'new forms of government such',
#  'government such as the parliamentary',
#  'the parliamentary system in england',
#  'in england the exploration of',
#  'exploration of the new world',
#  'new world the renaissance also',
#  'renaissance also saw the beginning',
#  'the beginning of european exploration',
#  'european exploration of the new',
#  'the new world this led',
#  'this led to the discovery',
#  'the discovery of new lands',
#  'new lands and peoples and',
#  'peoples and it had a',
#  'had a profound impact on',
#  'impact on european culture and',
#  'culture and society the renaissance',
#  'the renaissance was a period',
#  'a period of great change',
#  'great change and innovation and',
#  'innovation and it had a',
#  'had a lasting impact on',
#  'impact on the development of',
#  'development of western civilization its',
#  'civilization its legacy is still',
#  'is still felt today in',
#  'today in art literature science',
#  'literature science and society football',
#  'society football known as soccer',
#  'as soccer in some parts',
#  'some parts of the world',
#  'the world stands as one',
#  'as one of the most',
#  'the most captivating and widely',
#  'and widely followed sports globally',
#  'sports globally with a rich',
#  'a rich history dating back',
#  'dating back centuries football has',
#  'football has evolved into a',
#  'into a cultural phenomenon that',
#  'phenomenon that transcends borders uniting',
#  'borders uniting people from diverse',
#  'from diverse backgrounds in their',
#  'in their shared passion for',
#  'passion for the game this',
#  'game this essay will delve',
#  'will delve into the multifaceted',
#  'the multifaceted world of football',
#  'of football exploring its origins',
#  'its origins its global appeal',
#  'global appeal the impact it',
#  'impact it has on societies',
#  'on societies and the undeniable',
#  'the undeniable thrill it brings',
#  'it brings to millions of',
#  'millions of fans worldwide the',
#  'worldwide the roots of football',
#  'of football can be traced',
#  'be traced back to ancient',
#  'to ancient civilizations where various',
#  'where various forms of the',
#  'of the sport were played',
#  'were played in different cultures',
#  'different cultures however it was',
#  'it was in medieval england',
#  'medieval england that the foundations',
#  'the foundations of modern football',
#  'modern football began to take',
#  'to take shape the game',
#  'the game gradually transformed from',
#  'transformed from chaotic and often',
#  'and often violent street contests',
#  'street contests into a more',
#  'a more organized and structured',
#  'and structured activity the establishment',
#  'the establishment of standardized rules',
#  'standardized rules in the 19th',
#  'the 19th century marked a',
#  'marked a pivotal moment giving',
#  'moment giving rise to the',
#  'to the sport we recognize',
#  'we recognize today as football',
#  'as football spread across continents',
#  'across continents it became more',
#  'became more than just a',
#  'just a game it became',
#  'it became a powerful force',
#  'powerful force that transcends linguistic',
#  'transcends linguistic cultural and geopolitical',
#  'and geopolitical boundaries the beautiful',
#  'the beautiful game as it',
#  'as it is affectionately called',
#  'affectionately called has become a',
#  'become a universal language fostering',
#  'language fostering connections and friendships',
#  'and friendships among individuals who',
#  'individuals who might otherwise have',
#  'otherwise have little in common',
#  'in common from the bustling',
#  'the bustling streets of rio',
#  'of rio de janeiro to',
#  'janeiro to the quiet villages',
#  'quiet villages in africa the',
#  'africa the sight of a',
#  'of a ball at ones',
#  'at ones feet invokes a',
#  'invokes a shared sense of',
#  'sense of joy and excitement',
#  'and excitement footballs global appeal',
#  'global appeal is epitomized by',
#  'epitomized by international competitions such',
#  'competitions such as the fifa',
#  'the fifa world cup where',
#  'cup where nations compete for',
#  'compete for glory on the',
#  'on the grandest stage the',
#  'stage the tournament not only',
#  'not only showcases athletic prowess',
#  'athletic prowess but also serves',
#  'also serves as a platform',
#  'a platform for countries to',
#  'countries to exhibit their cultural',
#  'their cultural diversity the fervor',
#  'the fervor and national pride',
#  'national pride that accompany these',
#  'accompany these events are unparalleled',
#  'are unparalleled uniting entire populations',
#  'entire populations in a collective',
#  'a collective celebration of the',
#  'of the sport clubs too',
#  'clubs too play a significant',
#  'a significant role in the',
#  'in the football narrative whether',
#  'narrative whether its the historic',
#  'the historic rivalries of european',
#  'of european powerhouses or the',
#  'or the passionate fan bases',
#  'fan bases of south american',
#  'south american teams club football',
#  'club football adds another layer',
#  'another layer of intensity and',
#  'intensity and drama to the',
#  'to the sport leagues around',
#  'leagues around the world such',
#  'world such as the english',
#  'the english premier league la',
#  'league la liga serie a',
#  'serie a and the bundesliga',
#  'the bundesliga captivate audiences with',
#  'audiences with their skillful displays',
#  'skillful displays and unpredictable outcomes',
#  'unpredictable outcomes ensuring that football',
#  'that football enthusiasts have a',
#  'have a year-round supply of',
#  'supply of excitement beyond its',
#  'beyond its entertainment value football',
#  'value football serves as a',
#  'as a powerful agent of',
#  'agent of social change in',
#  'change in many communities the',
#  'communities the sport acts as',
#  'acts as a catalyst for',
#  'catalyst for unity providing a',
#  'providing a common ground where',
#  'ground where people can come',
#  'can come together irrespective of',
#  'irrespective of their differences football',
#  'differences football has been employed',
#  'been employed as a tool',
#  'a tool for social development',
#  'social development with initiatives focusing',
#  'initiatives focusing on using the',
#  'using the sport to address',
#  'to address issues like poverty',
#  'like poverty inequality and discrimination',
#  'and discrimination organizations and charities',
#  'and charities leverage the sports',
#  'the sports popularity to drive',
#  'to drive positive change emphasizing',
#  'change emphasizing values such as',
#  'such as teamwork discipline and',
#  'discipline and resilience the impact',
#  'the impact of football on',
#  'football on the economic landscape',
#  'economic landscape is also noteworthy',
#  'also noteworthy the sport has',
#  'sport has become a multi-billion-dollar',
#  'a multi-billion-dollar industry with clubs',
#  'with clubs signing lucrative sponsorship',
#  'lucrative sponsorship deals television rights',
#  'television rights agreements and merchandise',
#  'and merchandise contracts the economic',
#  'the economic influence extends to',
#  'extends to host countries of',
#  'countries of major tournaments which',
#  'tournaments which experience a surge',
#  'a surge in tourism and',
#  'tourism and infrastructure development the',
#  'development the football industrys economic',
#  'industrys economic footprint is vast',
#  'is vast contributing significantly to',
#  'significantly to job creation and',
#  'creation and stimulating economic growth',
#  'economic growth despite its widespread',
#  'its widespread popularity football is',
#  'football is not without its',
#  'without its challenges issues such',
#  'issues such as corruption racism',
#  'corruption racism and the immense',
#  'the immense pressure on players',
#  'on players can cast a',
#  'cast a shadow over the',
#  'over the sport efforts to',
#  'efforts to address these concerns',
#  'these concerns are ongoing with',
#  'ongoing with governing bodies and',
#  'bodies and organizations working towards',
#  'working towards creating a more',
#  'a more inclusive and equitable',
#  'and equitable football environment in',
#  'environment in conclusion footballs journey',
#  'footballs journey from its humble',
#  'its humble beginnings to its',
#  'to its current status as',
#  'status as a global phenomenon',
#  'global phenomenon is a testament',
#  'a testament to its enduring',
#  'its enduring appeal the sports',
#  'the sports ability to transcend',
#  'to transcend cultural linguistic and',
#  'linguistic and geographical barriers speaks',
#  'barriers speaks to its universal',
#  'its universal allure whether its',
#  'whether its the passion of',
#  'passion of fans in packed',
#  'in packed stadiums the dazzling',
#  'the dazzling skills of players',
#  'of players on the field',
#  'the field or the positive',
#  'the positive impact on societies',
#  'on societies football continues to',
#  'continues to capture the hearts',
#  'the hearts and minds of',
#  'minds of millions making it',
#  'making it more than just',
#  'than just a gameits a',
#  'gameits a shared experience that',
#  'experience that unites us all',
#  'us all i have a',
#  'have a 1980 model ferrari',
#  'model ferrari it is a']

# %%
startt = time.time()

testing = 0
levenshtein_results_mw = {}
levenshtein_threshold = 2

min_distance = 9999

for word in multiwords: 

    candidates = []
    
    levenshtein_candidates = ex_words.find({"$text": {"$search": word}})

    listing = time.time()
    levenshtein_candidates = [candidate["word"] for candidate in levenshtein_candidates]
    testing += time.time()-listing
    
    if any(char for char in word if char.isdigit() or char == '-'):
            
        clean_word = re.sub(r'[0-9-]', '', word)

        new_candidates = ex_words.find({"$text": {"$search": clean_word}})
        new_candidates = [candidate["word"] for candidate in new_candidates]

        all_candidates = list(set(levenshtein_candidates + new_candidates))
        
    else:
        all_candidates = list(set(levenshtein_candidates))
    
    for candidate in all_candidates:
        
        if(len(candidate.split()) < 2):
            continue

        current_distance = distance(word, candidate)
        
        check_distance = len(candidate)+current_distance-len(word)
        
        if check_distance <= levenshtein_threshold:
            
            candidates.append(candidate)
        
    if candidates:
        levenshtein_results_mw[word] = candidates

endt = time.time()

# %%
levenshtein_results_mw
# Out:
# {'of environmental protection lies the': ['environmental policy'],
#  'burning of fossil fuels releases': ['fossil fuels'],
#  'fuels releases greenhouse gases such': ['greenhouse gas'],
#  'environmental protection it entails meeting': ['environmental policy'],
#  'environmental protection adopting sustainable lifestyle': ['environmental policy'],
#  'to environmental protection overexploitation of': ['environmental policy'],
#  'environmental degradation adopting circular economy': ['environmental policy'],
#  'enforcing environmental policies and fostering': ['environmental policy'],
#  'the sports popularity to drive': ['hard drive'],
#  'football on the economic landscape': ['economic landscape'],
#  'economic landscape is also noteworthy': ['economic landscape']}

# %%
endt-startt
# Out:
# 31.8282368183136

# %%
testing
# Out:
# 30.666704893112183

# %% [markdown]
# ## Find the words inside the text

# %%
levenshtein_results_mw_list = list(levenshtein_results_mw.values())
levenshtein_results_mw_final = [sublist for sublist in levenshtein_results_mw]
levenshtein_results_list = list(levenshtein_results.values())
levenshtein_results_final = [sublist for sublist in levenshtein_results]
all_words_found = results + results_mw + levenshtein_results_final + levenshtein_results_mw_final
final_result = list(set(all_words_found))

# %%
print(final_result)
# Out:
# ['instigating', 'observation', 'land', 'brings', 'well', 'about', 'significant', 'intricate', 'where', 'press', 'lead', 'peoples', 'enforcing', 'industrys', 'this', 'globally', 'forestry', 'centuries', 'thinking', 'focusing', 'preserve', 'passionate', 'range', 'fuels releases greenhouse gases such', 'additionally', 'responsibility', 'role', 'web', 'diversity', 'felt', 'should', 'enacting', 'history', 'adopting', 'beginning', 'south', 'into', 'but', 'knowledge', 'overexploitation', 'exploring', 'emissions', 'dissemination', 'job', 'new', 'wider', 'havens', 'science', 'informed', 'infrastructure', 'environmental protection it entails meeting', 'contracts', 'modern', 'responsible', 'collective', 'fragile', 'environmental degradation adopting circular economy', 'period', 'can', 'possible', 'protected', 'street', 'poverty', 'endangering', 'discovery', 'embracing', 'status', 'beautiful', 'it', 'contests', 'fervor', 'too', 'disposal', 'equitable', 'across', 'enduring', 'artists', 'innovation', 'testament', 'promoting', 'recycling', 'rediscover', 'regulations', 'produce', 'immense', 'number', 'experience', 'rise', 'pressing', 'barriers', 'despite', 'rivers', 'habitats', 'which', 'outcomes', 'working', 'dazzling', 'european', 'areas', 'efficiently', 'exhaust', 'events', 'by', 'unsustainable', 'believed', 'adoption', 'runoff', 'difference', 'safe', 'back', 'finite', 'soccer', 'environmental', 'spur', 'teams', 'roots', 'tournament', 'traced', 'rate', 'continues', 'geographical', 'changes', 'degraded', 'geopolitical', 'upheaval', 'releases', 'civilization', 'sustains', 'needs', 'ferrari', 'exhibit', 'essay', 'greek', 'emphasize', 'include', 'use', 'current', 'affects', 'became', 'disturbances', 'programs', 'quiet', 'sonnet', 'liga', 'contributing', 'excitement', 'solar', 'pivotal', 'together', 'forms', 'cultural', 'air', 'de', 'audiences', 'leads', 'national', 'positive', 'instrumental', 'inequality', 'organizations', 'and', 'supports', 'pressure', 'model', 'small', 'society', 'discoveries', 'were', 'linguistic', 'parks', 'transcends', 'ideas', 'political', 'economic landscape is also noteworthy', 'charities', 'teamwork', 'most', 'achieve', 'epitomized', 'enforce', 'is', 'power', 'evident', 'investing', 'not', 'allows', 'only', 'allure', 'including', 'uniting', 'great', 'result', 'achievements', 'burning', 'fifa', 'drive', 'discrimination', 'incentives', 'water', 'invokes', 'endangered', 'unparalleled', 'skillful', 'people', 'on', 'ball', 'stimulating', 'marked', 'key', 'interest', 'biodiversity', 'harmful', 'beyond', 'compete', 'or', 'each', 'inaction', 'books', 'population', 'green', 'in', 'requires', 'passion', 'concerted', 'encouraged', 'agricultural', 'creating', 'drama', 'larger', 'showcases', 'sea', 'products', 'severe', 'economic', 'societies', 'gradually', 'natural', 'from', 'widespread', 'renewable', 'encompass', 'provides', 'circular', 'we', 'policies', 'underestimated', 'addressing', 'transcend', 'friendly', 'expression', 'multiplied', 'agreements', 'however', 'philosophers', 'system', 'behavior', 'feet', 'while', 'gases', 'there', 'nice', 'things', 'bustling', 'like', 'ones', 'speaks', 'exploration', 'implement', 'characterized', 'club', 'serves', 'heliocentric', 'surge', 'degradation', 'just', 'stands', 'field', 'substantial', 'legacy', 'root', 'creativity', 'protection', 'technologies', 'activities', 'been', 'appeal', 'chaotic', 'cheaply', 'ancient', 'explore', 'health', 'soil', 'thrill', 'life', 'threatening', 'literature', 'emphasis', 'interconnected', 'reserves', 'environment', 'harmonious', 'fan', 'celebration', 'otherwise', 'bases', 'businesses', 'protecting', 'their', 'living', 'establishing', 'lucrative', 'greenhouse', 'fostering', 'contaminates', 'become', 'learning', 'growth', 'contributes', 'league', 'urgent', 'sport', 'common', 'methane', 'pollution', 'structured', 'management', 'help', 'leading', 'sponsorship', 'come', 'deals', 'providing', 'who', 'culture', 'activity', 'resulting', 'rio', 'rules', 'racism', 'ec ...

# %%
for word in final_result:
    word_nums = []
    for i in range(len(words)):
        if(word == words[i].lower()):
            word_nums.append(i)

    print(f'The word positions of the word "{word}" are {word_nums} ')
# Out:
# The word positions of the word "instigating" are [345]
# The word positions of the word "observation" are [1150]
# The word positions of the word "land" are [311]
# The word positions of the word "brings" are [1405]
# The word positions of the word "well" are [811]
# The word positions of the word "about" are [1025]
# The word positions of the word "significant" are [195, 243, 609, 1040, 1636]
# The word positions of the word "intricate" are [153]
# The word positions of the word "where" are [1422, 1582, 1735]
# The word positions of the word "press" are [1060, 1180, 1183]
# The word positions of the word "lead" are [626]
# The word positions of the word "peoples" are [1281]
# The word positions of the word "enforcing" are [732]
# The word positions of the word "industrys" are [1839]
# The word positions of the word "this" are [17, 58, 858, 962, 1045, 1158, 1236, 1272, 1378]
# The word positions of the word "globally" are [1348]
# The word positions of the word "forestry" are [493]
# The word positions of the word "centuries" are [796, 1355]
# The word positions of the word "thinking" are [922]
# The word positions of the word "focusing" are [1756]
# The word positions of the word "preserve" are [26]
# The word positions of the word "passionate" are [1652]
# The word positions of the word "range" are [486]
# The word positions of the word "fuels releases greenhouse gases such" are []
# The word positions of the word "additionally" are [559]
# The word positions of the word "responsibility" are [22, 343, 696]
# The word positions of the word "role" are [337, 586, 1637]
# The word positions of the word "web" are [154]
# The word positions of the word "diversity" are [1610]
# The word positions of the word "felt" are [1319]
# The word positions of the word "should" are [354, 393, 616]
# The word positions of the word "enacting" are [730]
# The word positions of the word "history" are [1352]
# The word positions of the word "adopting" are [590, 665]
# The word positions of the word "beginning" are [1264]
# The word positions of the word "south" are [1656]
# The word positions of the word "into" are [187, 1359, 1382, 1460]
# The word positions of the word "but" are [194, 1598]
# The word positions of the word "knowledge" are [902, 1212]
# The word positions of the word "overexploitation" are [648]
# The word positions of the word "exploring" are [1388]
# The word positions of the word "emissions" are [254]
# The word positions of the word "dissemination" are [1210]
# The word positions of the word "job" are [1847]
# The word positions of the word "new" are [862, 889, 966, 976, 990, 1004, 1012, 1054, 1137, 1147, 1216, 1242, 1257, 1270, 1278]
# The word positions of the word "wider" are [1209]
# The word positions of the word "havens" are [547]
# The word positions of the word "science" are [1324]
# The word positions of the word "informed" are [1090]
# The word positions of the word "infrastructure" are [1835]
# The word positions of the word "environmental protection it entails meeting" are []
# The word positions of the word "contracts" are [1817]
# The word positions of the word "modern" are [1443]
# The word positions of the word "responsible" are [638]
# The word positions of the word "collective" are [444, 695, 1627]
# The word positions of the word "fragile" are [6]
# The word positions of the word "environmental degradation adopting circular economy" are []
# The word positions of the word "period" are [778, 814, 1096, 1297]
# The word positions of the word "can" are [80, 421, 510, 562, 605, 625, 675, 743, 1415, 1737, 1874]
# The word positions of the word "possible" are [1064, 1197]
# The word positions of the word "protected" are [536]
# The word positions of the word "street" are [1458]
# The word positions of the word "poverty" are [1765]
# The word positions of the word "endangering" are [287]
# The word positions of the word "discovery" are [1276]
# The word positions of the word "embracing" are [725]
# The word positions of the word "status" are [1914]
# The word positions of the word "beautiful" are [1513]
# The word positions of the word "it" are [19, 27, 72, 461, 797, 1063, 1103, 1113, 1194, 1196, 1283, 1304, 1396, 1404, 1434, 1493, 1500, 1516, 1975, 1994]
# The word positions of the word "contests" are [1459]
# The word positions of the word "fervor" are [1612]
# The word positions of the word "too" are [1633]
# The word positions of the word "disposal" are [302]
# The word positions of the word "equitable" are [1900]
# The word positions of the word "across" are [633, 1491]
# The word positions of the word "enduring" are [1924]
# The word positions of the word "artists" are [855, 1007]
# The word positions of the word "innovation" are [1111, 1302]
# The word positions of the word "testament" are [1921]
# The word positions of the word "promoting" are [384]
# The word positions of the word "recycling" are [671]
# The word positions of the word "rediscover" are [844]
# The word positions of the word "regulations" are [399]
# The word positions of the word "produce" are [1066, 1199]
# The word positions of the word "immense" are [1870]
# The word positions of the word "number" are [827, 988, 1162, 1226]
# The word positions of the word "experience" are [1829, 1983]
# The word positions of the word "rise" are [927, 1481]
# The word positions of the word "pressing" are [165]
# The word positions of the word "barriers" are [1935]
# The word positions of the word "despite" are [1853]
# The word positions of the word "rivers" are [279]
# The word positions of the word "habitats" are [147, 573]
# The word positions of the word "which" are [35, 109, 669, 872, 1061, 1083, 1205, 1828]
# The word positions of the word "outcomes" are [630, 1696]
# The word positions of the word "working" are [1893]
# The word positions of the word "dazzling" are [1951]
# The word positions of the word "european" are [1266, 1289, 1648]
# The word positions of the word "areas" are [537]
# The word positions of the word "efficiently" are [1071, 1204]
# The word positions of the word "exhaust" are [257]
# The word positions of the word "events" are [214, 1619]
# The word positions of the word "by" are [119, 124, 252, 300, 570, 652, 724, 825, 1573]
# The word positions of the word "unsustainable" are [653]
# The word positions of the word "believed" are [904, 945]
# The word positions of the word "adoption" are [417]
# The word positions of the word "runoff" are [277]
# The word positions of the word "difference" are [958]
# The word positions of the word "safe" are [546]
# The word positions of the word "back" are [1354, 1418]
# The word positions of the word "finite" are [659]
# The word positions of the word "soccer" are [1330]
# The word positions of the word "environmental" are [40, 53, 91, 359, 385, 398, 436, 459, 588, 646, 663, 679, 733, 740]
# The word positions of the word "spur" are [511]
# The word positions of the word "teams" are [1658]
# The word positions of the word "roots" are [1412]
# The word positions of the word "tournament" are [1592]
# The word positions of the word "traced" are [1417]
# The word positions of the word "rate" are [33]
# The word positions of the word "continues" are [1965]
# The word positions of the word "geographical" are [1934]
# The word positions of the word "changes" are [622]
# The word positions of the word "degraded" are [569]
# The word positions of the word "geopolitical" are [1510]
# The word positions of the word "upheaval" are [820]
# The word positions of the word "releases" are [178]
# The word positions of the word "civilization" are [1123, 1314]
# The word positions of the word "sustains" are [9]
# The word positions of the word "needs" are [465, 480]
# The word positions of the word "ferrari" are [1993]
# The word positions of the word "exhibit" are [1607]
# The word positions of the word "essay" are [59, 1002, 1379]
# The word positions of the word "greek" are [851]
# The word positions of the word "emphasize" are [670]
# The word positions of the word "include" are [208, 1133]
# The word positions of the word "use" are [1146]
# The word positions of the word "current" are [70, 720, 1913]
# The word positions of the word "affects" are [258]
# The word positions of the word "became" are [1494, 1501]
# The word positions of the word "disturbances" are [558]
# The word positions of the word "programs" are [361]
# The word positions of the word "quiet" are [1548]
# The word positions of the word "sonnet" are [997]
# The word positions of the word "liga" are [1682]
# The word positions of the word "contributing" are [577, 1844]
# The word positions of the word "excitement" are [1567, 1706]
# The word positions of the word "solar" are [1173]
# The word positions of the word "pivotal" are [1478]
# The word positions of the word "together" are [1739]
# The word positions of the word "forms" are [240, 980, 994, 1005, 1217, 1243, 1424]
# The word positions of the word "cultural" are [781, 1099, 1361, 1508, 1609, 1931]
# The word positions of the word "air" are [248]
# The word positions of the word "de" are [1544]
# The word positions of the word "audiences" are [1689]
# The word positions of the word "leads" are [132]
# The word positions of the word "national" are [439, 540, 1614]
# The word positions of the word "positive" are [629, 1778, 1960]
# The word positions of the word "instrumental" are [382]
# The word positions of the word "inequality" are [1766]
# The word positions of the word "organizations" are [349, 708, 1769, 1892]
# The word positions of the word "and" are [5, 25, 74, 78, 102, 129, 138, 185, 207, 215, 230, 255, 261, 275, 281, 286, 312, 324, 332, 344, 351, 370, 395, 407, 418, 424, 441, 492, 499, 507, 530, 534, 542, 551, 576, 601, 635, 661, 672, 684, 694, 706, 715, 721, 731, 735, 757, 782, 808, 818, 845, 852, 856, 870, 880, 898, 915, 924, 951, 971, 978, 992, 1000, 1008, 1014, 1016, 1070, 1081, 1089, 1100, 1110, 1112, 1151, 1203, 1280, 1282, 1291, 1301, 1303, 1325, 1344, 1400, 1455, 1464, 1509, 1527, 1566, 1613, 1666, 1685, 1694, 1767, 1770, 1786, 1815, 1834, 1849, 1868, 1891, 1899, 1933, 1970]
# The word positions of the word "supports" are [158]
# The word positions of the word "pressure" are [1871]
# The word positions of the word "model" are [1170, 1992]
# The word positions of the word "small" are [621]
# The word positions of the word "society" are [1292, 1326]
# The word positions of the word "discoveries" are [1165]
# The word positions of the word "were" are [1224, 1428]
# The word positions of the word "linguistic" are [1507, 1932]
# The word positions of the word "parks" are [541]
# The word positions of the word "transcends" are [1364, 1506]
# The word positions of the word "ideas" are [1013]
# The word positions of the word "political" are [819]
# The word positions of the word "economic landscape is also noteworthy" are []
# The word positions of the word "charities" are [1771]
# The word positions of the word "teamwork" are [1784]
# The word positions of the word "most" are [164, 1127, 1188, 1342]
# The word positions of the word "achieve" are [908]
# The word positions of the word "epitomized" are [1572]
# The word positions of the word "enforce" are [396]
# The word positions of the word "is" are [2, 20, 116, 170, 433, 451, 643, 691, 755, 1317, 1517, 1571, 1796, 1842, 1858, 1919, 1995]
# The word positions of the word "power" are [612]
# The word positions of the word "evident" are [56]
# The word positions of the word "investing" are [503]
# The word positions of the word "not" are [617, 1593, 1859]
# The word positions of the word "allows" are [552]
# The word positions of the word "only" are [1594]
# The word positions of the word "allure" are [1940]
# The word positions of the word "including" are [831, 995]
# The word positions of the word "uniting" are [1366, 1622]
# The word positions of the word "great" are [780, 816, 909, 1098, 1108, 1299]
# The word positions of the word "result" are [1074]
# The word positions of the word "achievements" are [1129]
# The word positions of the word "burning" are [174]
# The word positions of the word "fifa" are [1579]
# The word positions of the word "drive" are [1777]
# The word positions of the word "discrimination" are [1768]
# The word positions of the word "incentives" are [409]
# The word positions of the word "water" are [266, 294]
# The word positions of the word "invokes" are [1560]
# The word positions of the word "endangered" are [549]
# The word positions of the word "unparalleled" are [1621]
# The word positions of the word "skillful" are [1692]
# The word positions of the word "people" are [1076, 1367, 1736]
# The word positions of the word "on" are [11, 292, 376, 387, 877, 938, 1118, 1288, 1309, 1398, 1587, 1757, 1792, 1872, 1955, 1962]
# The word positions of the word "ball" are [1556]
# The word positions of the word "stimulating" are [1850]
# The word positions of the word "marked" are [1476]
# The word positions of the word "key" are [453, 829]
# The word positions of the word "interest" are [803, 834]
# The word positions of the word "biodiversity" are [137, 532]
# The word positions of the word "harmful" are [402]
# The word positions of the word "beyond" are [1707]
# The word positions of the word "compete" are [1584]
# The word positions of the word "or" are [1650, 1958]
# The word positions of the word "each" are [947]
# The word positions of the word "inaction" are [712]
# The word positions of the word "books" are [1067, 1200]
# The word positions of the word "population" are [1091]
# The word positions of the word "green" are [505]
# The word positions of the word "in" are [57, 197, 237, 338, 383, 455, 504, 587, 623, 686, 788, 804, 835, 959, 1042, 1048, 1251, 1321, 1331, 1371, 1430, 1436, 1472, 1536, 1550, 1625, 1638, 1720, 1832, 1903, 1947]
# The word positions of the word "requires" are [698]
# The word positions of the word "passion" are [1374, 1944]
# The word positions of the word "concerted" are [700]
# The word positions of the word "encouraged" are [917]
# The word positions of the word "agricultural" are [130, 276, 310]
# The word positions of the word "creating" are [1895]
# The word positions of the word "drama" are [1667]
# The word positions of the word "larger" are [389]
# The word positions of the word "showcases" are [1595]
# The word positions of the word "sea" are [210]
# The word positions of the word "products" are [604]
# The word positions of the word "severe" are [714]
# The word positions of the word "economic" are [512, 1794, 1819, 1840, 1851]
# The word positions of the word "societies" are [79, 325, 636, 1399, 1963]
# The word positions of the word "gradually" are [1451]
# The word positions of the word "natural" are [146, 641, 1156]
# The word positions of the word "from" are [46, 269, 489, 556, 790, 1368, 1453, 1538, 1907]
# The word positions of the word "widespread" are [1855]
# The word positions of the word "renewable" are [415, 500]
# The word positions of the word "encompass" are [483]
# The word positions of the word "provides" are [545]
# The word positions of the word "circular" are [666]
# The word positions of the word "we" are [60, 742, 760, 1023, 1485]
# The word positions of the word "policies" are [734]
# The word positions of the word "underestimated" are [619]
# The word positions of the word "addressing" are [223]
# The word positions of the word "transcend" are [438, 1930]
# The word positions of the word "friendly" are [429]
# The word positions of the word "expression" are [972]
# The word positions of the word "multiplied" are [632]
# The word positions of the word "agreements" are [1814]
# The word positions of the word "however" are [1433]
# The word positions of the word "philosophers" are [857]
# The word positions of the word "system" are [1174, 1233, 1250]
# The word positions of the word "behavior" are [624]
# The word positions of the word "feet" are [1559]
# The word positions of the word "while" are [514]
# The word positions of the word "gases" are [180]
# The word positions of the word "there" are [933, 1037, 1223]
# The word positions of the word "nice" are [1997]
# The word positions of the word "things" are [369, 910]
# The word positions of the word "bustling" are [1540]
# The word positions of the word "like" are [1764]
# The word positions of the word "ones" are [1558]
# The word positions of the word "speaks" are [1936]
# The word positions of the word "exploration" are [1254, 1267]
# The word positions of the word "implement" are [357]
# The word positions of the word "characterized" are [824]
# The word positions of the word "club" are [1659]
# The word positions of the word "serves" are [1600, 1712]
# The word positions of the word "heliocentric" are [1169]
# The word positions of the word "surge" are [1831]
# The word positions of the word "degradation" are [41, 664]
# The word positions of the word "just" are [1497, 1978]
# The word positions of the word "stands" are [1337]
# The word positions of the word "field" are [1957]
# The word positions of the word "substantial" are [628]
# The word positions of the word "legacy" are [1316]
# The word positions of the word "root" are [225]
# The word positions of the word "creativity" are [923]
# The word positions of the word "protection" are [92, 386, 460, 589, 647]
# The word positions of the word "technologies" are [506, 1055]
# The word positions of the word "activities" are [37, 121, 375, 488, 521]
# The word positions of the word "been" are [568, 1746]
# The word positions of the word "appeal" are [1393, 1570, 1925]
# The word positions of the word "chaotic" are [1454]
# The word positions of the word "cheaply" are [1069, 1202]
# The word positions of the word "ancient" are [850, 1420]
# The word positions of the word "explore" are [62, 1011]
# The word positions of the word "health" are [260, 317]
# The word positions of the word "soil" are [296]
# The word positions of the word "thrill" are [1403]
# The word positions of the word "life" are [10, 156, 285, 1033, 1044]
# The word positions of the word "threatening" are [167]
# The word positions of the word "literature" are [809, 881, 1323]
# The word positions of the word "emphasis" are [937]
# The word positions of the word "interconnected" are [101]
# The word positions of the word "reserves" are [544]
# The word positions of the word "environment" are [1, 68, 169, 221, 247, 321, 529, 690, 1902]
# The word positions of the word "harmonious" are [747]
# The word positions of the word "fan" are [1653]
# The word positions of the word "celebration" are [1628]
# The word positions of the word "otherwise" are [1533]
# The word positions of the word "bases" are [1654]
# The word positions of the word "businesses" are [423]
# The word positions of the word "protecting" are [66, 219, 527, 688]
# The word positions of the word "their" are [478, 912, 1372, 1608, 1691, 1742]
# The word positions of the word "living" are [368]
# The word positions of the word "establishing" are [533]
# The word positions of the word "lucrative" are [1809]
# The word positions of the word "greenhouse" are [179]
# The word positions of the word "fostering" are [339, 736, 1525]
# The word positions of the word "contaminates" are [278]
# The word positions of the word "become" are [1521, 1802]
# The word positions of the word "learning" are [806, 837]
# The word positions of the word "growth" are [513, 1030, 1041, 1852]
# The word positions of the word "contributes" are [139, 262]
# The word positions of the word "league" are [1680]
# The word positions of the word "urgent" are [693]
# The word positions of the word "sport" are [1427, 1484, 1631, 1670, 1724, 1760, 1800, 1880]
# The word positions of the word "common" are [1537, 1733]
# The word positions of the word "methane" are [186]
# The word positions of the word "pollution" are [49, 236, 249, 267, 297, 408]
# The word positions of the word "structured" are [1465]
# The word positions of the word "management" are [639]
# The word positions of the word "help" are [563, 676]
# The word positions of the word "leading" are [190]
# The word positions of the word "sponsorship" are [1810]
# The word positions of the word "come" are [773, 1738]
# The word positions of the word "deals" are [1811]
# The word positions of the word "providing" are [572, 1731]
# The word positions of the word "who" are [1531]
# The word positions of the word "culture" are [1290]
# The word positions of the word "activity" are [1466]
# The word positions of the word "resulting" are [268]
# The word positions of the word "rio" are [1543]
# The word positions of the word "rules" are [1471]
# The word positions of the word "racism" are [1867]
# The word positions of the word "ecosystems" are [99, 159, 218, 553, 565]
# The word positions of the word "english" are [1678]
# The word positions of the word "around" are [1672]
# The word positions of the word "sight" are [1553]
# The word positions of the word "boundaries" are [1511]
# The word positions of the word "improper" are [301]
# The word positions of the word "africa" are [1551]
# The word positions of the word "narrative" are [1641]
# The word positions of the word "governments" are [347, 391, 705]
# The word positions of the word "footprint" are [518, 1841]
# The word positions of the word "athletic" are [1596]
# The word positions of the word "differences" are [1743]
# The word positions of the word "all" are [367, 1987]
# The word positions of the word "collectively" are [606]
# The word positions of the word "affectionately" are [1518]
# The word positions of the word "emphasizing" are [1780]
# The word positions of the word "will" are [61, 763, 1380]
# The word positions of the word "art" are [807, 879, 1322]
# The word positions of the word "inclusive" are [1898]
# The word positions of the word "when" are [631]
# The word positions of the word "reducing" are [596, 673]
# The word positions of the word "increase" are [196]
# The word positions of the word "leagues" are [1671]
# The word positions of the word "meeting" are [463]
# The word positions of the word "caused" are [251, 299]
# The word positions of the word "cup" are [1581]
# The word positions of the word "quality" are [308]
# The word positions of the word "known" are [1328]
# The word positions of the word "historic" are [1645]
# The word positions of the word "the sports popularity to drive" are []
# The word positions of the word "of" are [16, 52, 65, 90, 107, 114, 136, 145, 155, 162, 175, 202, 227, 272, 303, 309, 342, 366, 373, 466, 473, 487, 497, 519, 613, 640, 649, 681, 702, 711, 719, 739, 767, 779, 801, 815, 828, 849, 867, 884, 895, 901, 920, 928, 941, 975, 986, 989, 1031, 1053, 1097, 1107, 1121, 1125, 1130, 1136, 1149, 1163, 1171, 1177, 1186, 1191, 1211, 1215, 1218, 1227, 1234, 1241, 1244, 1255, 1265, 1268, 1277, 1298, 1312, 1334, 1340, 1386, 1408, 1413, 1425, 1442, 1469, 1542, 1554, 1564, 1629, 1647, 1655, 1664, 1705, 1717, 1741, 1790, 1825, 1945, 1953, 1972]
# The word positions of the word "crucial" are [336, 585]
# The word positions of the word "captivate" are [1688]
# The word positions of the word "countries" are [1605, 1824]
# The word positions of the word "american" are [1657]
# The word positions of the word "experimentation" are [1152]
# The word positions of the word "major" are [1826]
# The word positions of the word "enthusiasts" are [1700]
# The word positions of the word "threats" are [71]
# The word positions of the word "are" are [38, 55, 100, 205, 381, 524, 713, 1620, 1886]
# The word positions of the word "awareness" are [333, 729]
# The word positions of the word "earth" are [12]
# The word positions of the word "entire" are [1623]
# The word positions of the word "patterns" are [655]
# The word positions of the word "fuels" are [177]
# The word positions of the word "entertainment" are [1709]
# The word positions of the word "appreciation" are [863, 967]
# The word positions of the word "feudal" are [1232]
# The word positions of the word "for" are [28, 127, 410, 458, 548, 574, 770, 864, 968, 1375, 1585, 1604, 1729, 1751]
# The word positions of the word "demand" are [126]
# The word positions of the word "individualism" are [929]
# The word positions of the word "threaten" are [716]
# The word positions of the word "oceans" are [282]
# The word positions of the word "alarming" are [32]
# The word positions of the word "critical" are [921]
# The word positions of the word "consequences" are [201, 710]
# The word positions of the word "bodies" are [1890]
# The word positions of the word "diverse" are [1369]
# The word positions of the word "levels" are [211]
# The word positions of the word "many" are [1721]
# The word positions of the word "individuals" are [77, 323, 581, 703, 906, 1530]
# The word positions of the word "allowed" are [1006]
# The word positions of the word "potential" are [954]
# The word positions of the word "renaissance" are [775, 822, 840, 878, 932, 982, 1036, 1093, 1132, 1142, 1193, 1222, 1260, 1294]
# The word positions of the word "moment" are [1479]
# The word positions of the word "waste" are [274, 305, 600, 674]
# The word positions of the word "its" are [238, 1315, 1389, 1391, 1643, 1708, 1854, 1861, 1908, 1912, 1923, 1938, 1942]
# The word positions of the word "importance" are [64, 894, 940]
# The word positions of the word "could" are [907]
# The word positions of the word "than" are [1496, 1977]
# The word positions of the word "alternatives" are [430]
# The word positions of the word "corruption" are [1866]
# The word positions of the word "some" are [1124, 1332]
# The word positions of the word "creation" are [1848]
# The word positions of the word "foundations" are [1441]
# The word positions of the word "inventions" are [1190]
# The word positions of the word "influence" are [876, 1820]
# The word positions of the word "different" are [1431]
# The word positions of the word "as" are [13, 182, 405, 414, 435, 539, 595, 620, 810, 812, 1057, 1072, 1167, 1247, 1329, 1338, 1488, 1515, 1577, 1601, 1676, 1713, 1726, 1748, 1783, 1865, 1915]
# The word positions of the word "entity" are [7]
# The word positions of the word "lies" are [93]
# The word positions of the word "acts" are [1725]
# The word positions of the word "these" are [293, 1003, 1618, 1884]
# The word positions of the word "be" are [618, 1416]
# The word positions of the word "through" are [911]
# The word positions of the word "widely" are [1345]
# The word positions of the word "ecological" are [517]
# The word positions of the word "various" are [239, 1423]
# The word positions of the word "wildlife" are [543, 575]
# The word positions of the word "freedom" are [970]
# The word positions of the word "causing" are [39]
# The word positions of the word "ensuring" are [1697]
# The word positions of the word "person" are [948]
# The word positions of the word "cultures" are [1432]
# The word positions of the word "developments" are [830]
# The word positions of the word "intensity" are [1665]
# The word positions of the word "sustainable" are [85, 233, 411, 449, 481, 490, 591, 726]
# The word positions of the word "scholars" are [841]
# The word positions of the word "dating" are [1353]
# The word positions of the word "platform" are [1603]
# The word positions of the word "heart" are [89]
# The word positions of the word "philosophy" are [890]
# The word positions of the word "tourism" are [1833]
# The word positions of the word "cast" are [1875]
# The word positions of the word "catalyst" are [1728]
# The word positions of the word "atmosphere" are [189]
# The word positions of the word "actions" are [76, 615]
# The word positions of the word "villages" are [1549]
# The word positions of the word "adopt" are [327]
# The word positions of the word "i" are [1988]
# The word positions of the word "methods" are [1139, 1148]
# The word positions of the word "social" are [817, 1718, 1752]
# The word positions of the word "conservation" are [419, 522]
# The word positions of the word "establishment" are [1468]
# The word positions of the word "planet" are [18, 378, 769]
# The word positions of the word "recover" are [555]
# The word positions of the word "took" are [786]
# The word positions of the word "recognize" are [1486]
# The word positions of the word "displays" are [1693]
# The word positions of the word "hazardous" are [304]
# The word positions of the word "fundamental" are [644]
# The word positions of the word "understanding" are [95]
# The word positions of the word "scientific" are [1138]
# The word positions of the word "due" are [1047]
# The word positions of the word "janeiro" are [1545]
# The word positions of the word "take" are [81, 1447]
# The word positions of the word "called" are [1519]
# The word positions of the word "backgrounds" are [1370]
# The word positions of the word "literary" are [979, 993]
# The word positions of the word "noteworthy" are [1798]
# The word positions of the word "transitioning" are [231]
# The word positions of the word "organized" are [1463]
# The word positions of the word "violent" are [1457]
# The word positions of the word "rivalries" are [1646]
# The word positions of the word "phenomenon" are [1362, 1918]
# The word positions of the word "restore" are [564]
# The word positions of the word "stringent" are [397]
# The word positions of the word "skills" are [1952]
# The word positions of the word "saw" are [983, 1262]
# The word positions of the word "accompany" are [1617]
# The word positions of the word "extraction" are [683]
# The word positions of the word "significantly" are [1845]
# The word positions of the word "weather" are [213]
# The word positions of the word "think" are [1024]
# The word positions of the word "time" are [752, 800, 1106]
# The word positions of the word "unity" are [1730]
# The word positions of the word "preserving" are [531]
# The word positions of the word "today" are [762, 1028, 1320, 1487]
# The word positions of the word "bundesliga" are [1687]
# The word positions of the word "environmental protection adopting sustainable lifestyle" are []
# The word positions of the word "prowess" are [1597]
# The word positions of the word "present" are [468]
# The word positions of the word "resource" are [682]
# The word positions of the word "choosing" are [602]
# The word positions of the word "consumption" are [598, 654, 685]
# The word positions of the word "has" are [42, 110, 1357, 1397, 1520, 1745, 1801]
# The word positions of the word "stewardship" are [741]
# The word positions of the word "species" are [150, 550]
# The word positions of the word "among" are [1529]
# The word positions of the word "driven" are [123, 651]
# The word positions of the word "captivating" are [1343]
# The word positions of the word "accelerates" are [662]
# The word positions of the word "competitions" are [1575]
# The word positions of the word "challenges" are [1228, 1862]
# The word positions of the word "whether" are [1642, 1941]
# The word positions of the word "writers" are [854, 1009]
# The word positions of the word "ongoing" are [1887]
# The word positions of the word "minds" are [1971]
# The word positions of the word "printing" are [1059, 1179, 1182]
# The word positions of the word "fossil" are [176]
# The word positions of the word "education" are [331, 360, 1080]
# The word positions of the word "undeniable" are [1402]
# The word positions of the word "universal" are [1523, 1939]
# The word positions of the word "discharge" are [271]
# The word positions of the word "meet" are [477]
# The word positions of the word "classical" are [805, 836, 865]
# The word positions of the word "loss" are [135]
# The word positions of the word "solutions" are [509]
# The word positions of the word "vehicular" are [256]
# The word positions of the word "emphasized" are [892]
# The word positions of the word "temperatures" are [199]
# The word positions of the word "interdependent" are [103]
# The word positions of the word "communities" are [634, 704, 1722]
# The word positions of the word "parliamentary" are [1249]
# The word positions of the word "signs" are [51]
# The word positions of the word "western" are [1122, 1313]
# The word positions of the word "making" are [1974]
# The word positions of the word "extreme" are [212]
# The word positions of the word "origins" are [1390]
# The word positions of the word "powerful" are [1503, 1715]
# The word positions of the word "la" are [1681]
# The word positions of the word "disruptions" are [216]
# The word positions of the word "means" are [222]
# The word positions of the word "television" are [1812]
# The word positions of the word "industrial" are [253, 273]
# The word positions of the word "unites" are [1985]
# The word positions of the word "years" are [115]
# The word positions of the word "international" are [431, 707, 1574]
# The word positions of the word "risks" are [314]
# The word positions of the word "they" are [916, 1017]
# The word positions of the word "at" are [34, 87, 1557]
# The word positions of the word "energy" are [234, 416, 501, 597]
# The word positions of the word "unpredictable" are [1695]
# The word positions of the word "entails" are [462]
# The word positions of the word "interconnectedness" are [365]
# The word positions of the word "to" are [23, 48, 82, 133, 140, 191, 217, 232, 245, 263, 315, 318, 356, 426, 446, 476, 494, 526, 554, 578, 627, 645, 753, 772, 793, 843, 860, 955, 964, 1010, 1019, 1050, 1065, 1079, 1085, 1145, 1153, 1160, 1198, 1207, 1229, 1238, 1274, 1406, 1419, 1446, 1482, 1546, 1606, 1668, 1761, 1776, 1822, 1846, 1882, 1911, 1922, 1929, 1937, 1966]
# The word positions of the word "irrespective" are [1740]
# The word positions of the word "that" are [8, 96, 157, 290, 362, 400, 566, 697, 785, 891, 905, 946, 1363, 1439, 1505, 1616, 1698, 1984]
# The word positions of the word "resources" are [642, 650, 660]
# The word positions of the word "coexistence" are [748]
# The word positions of the word "human" are [36, 120, 259, 288, 316, 374, 520, 896]
# The word positions of the word "collaborate" are [355]
# The word positions of the word "cooperation" are [432]
# The word positions of the word "governing" are [1889]
# The word positions of the word "without" are [469, 1860]
# The word positions of the word "institutions" are [353]
# The word positions of the word "maintaining" are [535]
# The word positions of the word "custodians" are [15]
# The word positions of the word "millions" are [113, 1407, 1973]
# The word positions of the word "own" are [479, 913]
# The word positions of the word "still" are [1318]
# The word positions of the word "personal" are [969]
# The word positions of the word "economy" are [667]
# The word positions of the word "embrace" are [427]
# The word positions of the word "must" are [326]
# The word positions of the word "values" are [1781]
# The word positions of the word "expansion" are [131]
# The word positions of the word "proportion" are [871]
# The word positions of the word "change" are [142, 172, 204, 229, 265, 346, 784, 1109, 1300, 1719, 1779]
# The word positions of the word "timber" are [128]
# The word positions of the word "populations" are [289, 1624]
# The word positions of the word "balance" are [106]
# The word positions of the word "traditional" are [1231]
# The word positions of the word "towards" are [745, 1894]
# The word positions of the word "ensure" are [83]
# The word positions of the word "civilizations" are [1421]
# The word positions of the word "highlight" are [363]
# The word positions of the word "artistic" are [977, 991]
# The word positions of the word "century" are [1475]
# The word positions of the word "agent" are [1716]
# The word positions of the word "game" are [1377, 1450, 1499, 1514]
# The word positions of the word "giving" are [1480]
# The word positions of the word "climate" are [141, 171, 203, 228, 264]
# The word positions of the word "parts" are [1333]
# The word positions of the word "primarily" are [250]
# The word positions of the word "development" are [450, 883, 919, 974, 985, 1052, 1120, 1135, 1214, 1240, 1311, 1753, 1836]
# The word positions of the word "countless" are [149]
# The word positions of the word "ground" are [1734]
# The word positions of the word "being" are [117]
# The word positions of the word "lifestyle" are [592]
# The word positions of the word "reason" are [897]
# The word positions of the word "environmentally" are [428]
# The word positions of the word "scale" are [390]
# The word positions of the word "football on the economic landscape" are []
# The word positions of the word "stadiums" are [1949]
# The word positions of the word "concerns" are [44, 1885]
# The word positions of the word "novel" are [999]
# The word positions of the word "a" are [3, 84, 192, 328, 335, 340, 388, 443, 452, 484, 584, 608, 737, 746, 777, 799, 813, 826, 832, 861, 874, 888, 935, 957, 965, 987, 1039, 1073, 1086, 1095, 1105, 1115, 1161, 1208, 1225, 1285, 1296, 1306, 1350, 1360, 1461, 1477, 1498, 1502, 1522, 1555, 1561, 1602, 1626, 1635, 1684, 1702, 1714, 1727, 1732, 1749, 1803, 1830, 1876, 1896, 1916, 1920, 1979, 1981, 1990, 1996]
# The word positions of the word "was" are [776, 798, 823, 887, 934, 949, 1038, 1046, 1094, 1104, 1184, 1295, 1435]
# The word positions of the word "minimize" are [677]
# The word positions of the word "delicate" are [105]
# The word positions of the word "lasting" are [1307]
# The word positions of the word "works" are [848]
# The word positions of the word "football" are [1327, 1356, 1387, 1414, 1444, 1489, 1640, 1660, 1699, 1711, 1744, 1791, 1838, 1857, 1901, 1964]
# The word positions of the word "spread" are [1490]
# The word positions of the word "such" are [181, 404, 413, 538, 594, 1056, 1166, 1246, 1576, 1675, 1782, 1864]
# The word positions of the word "shadow" are [1877]
# The word positions of the word "future" are [29, 86, 474, 722, 766]
# The word positions of the word "sports" are [1347, 1774, 1927]
# The word positions of the word "growing" are [936]
# The word positions of the word "burning of fossil fuels releases" are []
# The word positions of the word "ideals" are [866]
# The word positions of the word "stage" are [1590]
# The word positions of the word "educational" are [352]
# The word positions of the word "roman" are [853]
# The word positions of the word "transformed" are [1452]
# The word positions of the word "earths" are [98, 658]
# The word positions of the word "extends" are [1821]
# The word positions of the word "principles" are [668]
# The word positions of the word "force" are [1504]
# The word positions of the word "also" are [582, 1261, 1599, 1797]
# The word positions of the word "approach" are [330]
# The word positions of the word "displaces" are [148]
# The word positions of the word "packed" are [1948]
# The word positions of the word "value" are [1710]
# The word positions of the word "glory" are [1586]
# The word positions of the word "protect" are [24, 319]
# The word positions of the word "wide" are [485]
# The word positions of the word "europe" are [789]
# The word positions of the word "followed" are [1346]
# The word positions of the word "invention" are [1176]
# The word positions of the word "nations" are [1583]
# The word positions of the word "shared" are [1373, 1562, 1982]
# The word positions of the word "premier" are [1679]
# The word positions of the word "discipline" are [1785]
# The word positions of the word "play" are [334, 583, 1634]
# The word positions of the word "industries" are [425]
# The word positions of the word "played" are [1429]
# The word positions of the word "rich" are [1351]
# The word positions of the word "footballs" are [1568, 1905]
# The word positions of the word "serie" are [1683]
# The word positions of the word "supply" are [1704]
# The word positions of the word "precious" are [4]
# The word positions of the word "one" are [161, 1185, 1339]
# The word positions of the word "have" are [567, 1534, 1701, 1989]
# The word positions of the word "powerhouses" are [1649]
# The word positions of the word "concept" are [454]
# The word positions of the word "evolved" are [111, 1358]
# The word positions of the word "the" are [0, 14, 31, 50, 63, 67, 69, 75, 88, 94, 97, 104, 125, 134, 143, 152, 163, 168, 173, 188, 200, 220, 224, 246, 270, 307, 320, 364, 371, 377, 456, 464, 467, 471, 495, 516, 528, 611, 637, 657, 678, 689, 699, 709, 717, 751, 758, 765, 774, 791, 794, 821, 839, 847, 882, 893, 899, 918, 926, 931, 939, 942, 953, 960, 973, 981, 984, 996, 998, 1001, 1021, 1026, 1029, 1035, 1051, 1058, 1092, 1119, 1126, 1131, 1134, 1141, 1155, 1168, 1172, 1175, 1178, 1181, 1187, 1192, 1213, 1221, 1230, 1239, 1248, 1253, 1256, 1259, 1263, 1269, 1275, 1293, 1310, 1335, 1341, 1376, 1383, 1394, 1401, 1411, 1426, 1440, 1449, 1467, 1473, 1483, 1512, 1539, 1547, 1552, 1578, 1588, 1591, 1611, 1630, 1639, 1644, 1651, 1669, 1673, 1677, 1686, 1723, 1759, 1773, 1788, 1793, 1799, 1818, 1837, 1869, 1879, 1926, 1943, 1950, 1956, 1959, 1968]
# The word positions of the word "had" are [873, 952, 1077, 1114, 1284, 1305]
# The word positions of the word "raised" are [43]
# The word positions of the word "sources" are [235, 295, 502]
# The word positions of the word "intellectual" are [783, 1101]
# The word positions of the word "study" are [846, 1154]
# The word positions of the word "disrupting" are [151]
# The word positions of the word "government" are [1219, 1235, 1245]
# The word positions of the word "threat" are [244]
# The word positions of the word "literate" are [1088]
# The word positions of the word "disrupted" are [118]
# The word positions of the word "vital" are [434]
# The word positions of the word "dioxide" are [184]
# The word positions of the word "beauty" are [868]
# The word positions of the word "made" are [1062, 1195]
# The word positions of the word "multifaceted" are [1384]
# The word positions of the word "sequestration" are [580]
# The word positions of the word "adds" are [1661]
# The word positions of the word "lakes" are [280]
# The word positions of the word "harming" are [283]
# The word positions of the word "require" are [442]
# The word positions of the word "encourage" are [422]
# The word positions of the word "over" are [112, 1878]
# The word positions of the word "sense" are [341, 738, 1563]
# The word positions of the word "clean" are [498]
# The word positions of the word "using" are [1758]
# The word positions of the word "place" are [787]
# The word positions of the word "global" are [198, 1392, 1569, 1917]
# The word positions of the word "joy" are [1565]
# The word positions of the word "humble" are [1909]
# The word positions of the word "work" are [744]
# The word positions of the word "language" are [1524]
# The word positions of the word "ability" are [472, 1928]
# The word positions of the word "causes" are [226]
# The word positions of the word "degrades" are [306]
# The word positions of the word "minimizing" are [515, 599]
# The word positions of the word "techniques" are [1015]
# The word positions of the word "access" are [1078]
# The word positions of the word "destruction" are [144]
# The word positions of the word "rising" are [209]
# The word positions of the word "vast" are [1843]
# The word positions of the word "harmony" are [869]
# The word positions of the word "rights" are [1813]
# The word positions of the word "leverage" are [1772]
# The word positions of the word "practices" are [403, 412, 482, 727]
# The word positions of the word "part" are [1049]
# The word positions of the word "capture" are [1967]
# The word positions of the word "distress" are [54]
# The word positions of the word "industry" are [1805]
# The word positions of the word "beginnings" are [1910]
# The word positions of the word "led" are [859, 963, 1084, 1159, 1206, 1237, 1273]
# The word positions of the word "agriculture" are [491]
# The word positions of the word "poses" are [241, 313]
# The word positions of the word "host" are [1823]
# The word positions of the word "journey" are [1906]
# The word positions of the word "tool" are [1750]
# The word positions of the word "initiatives" are [380, 561, 1755]
# The word positions of the word "effectively" are [322, 448]
# The word positions of the word "address" are [447, 1762, 1883]
# The word positions of the word "another" are [242, 1662]
# The word positions of the word "world" are [961, 1027, 1157, 1258, 1271, 1336, 1385, 1580, 1674]
# The word positions of the word "clubs" are [1632, 1807]
# The word positions of the word "nature" are [108, 750]
# The word positions of the word "an" are [692]
# The word positions of the word "conclusion" are [687, 1904]
# The word positions of the word "profound" are [875, 1116, 1286]
# The word positions of the word "employed" are [1747]
# The word positions of the word "act" are [754]
# The word positions of the word "hearts" are [1969]
# The word positions of the word "began" are [842, 1144, 1445]
# The word positions of the word "important" are [1128, 1164, 1189]
# The word positions of the word "grandest" are [1589]
# The word positions of the word "popularity" are [1775, 1856]
# The word positions of the word "merchandise" are [1816]
# The word positions of the word "during" are [838, 930, 1034, 1140, 1220]
# The word positions of the word "aquatic" are [284]
# The word positions of the word "issues" are [166, 437, 1763, 1863]
# The word positions of the word "car" are [1998]
# The word positions of the word "comprehensive" are [358]
# The word positions of the word "gradual" are [193]
# The word positions of the word "promotion" are [496]
# The word positions of the word "of environmental protection lies the" are []
# The word positions of the word "enact" are [394]
# The word positions of the word "integral" are [525]
# The word positions of the word "scientists" are [1143]
# The word positions of the word "our" are [21, 768]
# The word positions of the word "helped" are [1018]
# The word positions of the word "humanists" are [903, 944]
# The word positions of the word "now" are [756]
# The word positions of the word "individual" are [614, 943]
# The word positions of the word "depletes" are [656]
# The word positions of the word "efforts" are [420, 523, 701, 914, 1881]
# The word positions of the word "unique" are [950]
# The word positions of the word "to environmental protection overexploitation of" are []
# The word positions of the word "impact" are [372, 610, 680, 1117, 1287, 1308, 1395, 1789, 1961]
# The word positions of the word "borders" are [440, 1365]
# The word positions of the word "ngos" are [350]
# The word positions of the word "standardized" are [1470]
# The word positions of the word "england" are [1252, 1438]
# The word positions of the word "generations" are [30, 475, 723, 771]
# The word positions of the word "limit" are [401]
# The word positions of the word "effort" are [445]
# The word positions of the word "ferment" are [1102]
# The word positions of the word "worldwide" are [45, 160, 392, 1410]
# The word positions of the word "landscape" are [1795]
# The word positions of the word "information" are [1082]
# The word positions of the word "urban" are [1032, 1043]
# The word positions of the word "renewed" are [802, 833]
# The word positions of the word "make" are [607, 761, 956]
# The word positions of the word "enforcing environmental policies and fostering" are []
# The word positions of the word "compromising" are [470]
# The word positions of the word "often" are [298, 1456]
# The word positions of the word "raising" are [728]
# The word positions of the word "us" are [1986]
# The word positions of the word "shape" are [764, 1020, 1448]
# The word positions of the word "rely" are [291]
# The word positions of the word "players" are [1873, 1954]
# The word positions of the word "might" are [1532]
# The word positions of the word "connections" are [1526]
# The word positions of the word "tournaments" are [1827]
# The word positions of the word "reforestation" are [560]
# The word positions of the word "friendships" are [1528]
# The word positions of the word "signing" are [1808]
# The word positions of the word "streets" are [1541]
# The word positions of the word "little" are [1535]
# The word positions of the word "pursuit" are [900]
# The word positions of the word "layer" are [1663]
# The word positions of the word "deforestation" are [47, 122, 406, 571]
# The word positions of the word "more" are [1068, 1075, 1087, 1201, 1462, 1495, 1897, 1976]
# The word positions of the word "carbon" are [183, 579]
# The word positions of the word "quest" are [457]
# The word positions of the word "fans" are [1409, 1946]
# The word positions of the word "pride" are [1615]
# The word positions of the word "continents" are [1492]
# The word positions of the word "delve" are [1381]
# The word positions of the word "faces" are [73]
# The word positions of the word "with" are [749, 1349, 1690, 1754, 1806, 1888]
# The word positions of the word "humanism" are [885, 886]
# The word positions of the word "choices" are [593, 759]
# The word positions of the word "way" are [1022]
# The word positions of the word "resilience" are [1787]
# The word positions of the word "medieval" are [1437]
# The word positions of the word "lands" are [1279]
# The word positions of the word "policy" are [379]
